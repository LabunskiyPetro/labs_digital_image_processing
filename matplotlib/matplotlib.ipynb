# %% [markdown]
# # MatplotLib

# %% [markdown]
# ## Імпорт бібліотек та пакетів

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Оскільки будем працювати з багатомірними масивами, імпортуємо бібліотеку **NumPy**.

# %%
import numpy as np

# %% [markdown]
# # Завдання
# ## 1. Створити Subplot із  4 графіків сінусоїди з різними частотами
#
# 1.1. Сформувати діапазон функції від 0 до 2 з кроком 0.01

# %%
start = 0
stop = 2
step = 0.01

t = np.arange(start,stop,step)

# %% [markdown]
# 1.2 Сформувати частоти сінусоїди

# %%
s1 = np.sin(2 * np.pi * t)
s2 = np.sin(3 * np.pi * t)
s3 = np.sin(4 * np.pi * t)
s4 = np.sin(5 * np.pi * t)

# %% [markdown]
# 1.3 Надрукувати графіки

# %%
plt.plot(t, s1, c='r',linewidth=2.0)
plt.plot(t, s2, c='b',linewidth=2.0)
plt.plot(t, s3, c='g',linewidth=2.0)
plt.plot(t, s4, c='black',linewidth=2.0)
plt.grid()
plt.show()

# %% [markdown]
# 1.2 Сформувати частоти сінусоїди

# %% [markdown]
# 1.2 Сформувати частоти сінусоїди

# %%
fig = plt.figure(figsize=(15,15))
ax0 = fig.add_subplot(2, 2, 1)
ax0.plot(t, s1, c='y',linewidth=2.0)
ax0.set(xlabel='x', ylabel='y', title='Сінус функція №1')
ax0.grid()

ax1 = fig.add_subplot(2, 2, 2)
ax1.plot(t, s2, c='y',linewidth=2.0)
ax1.set(xlabel='x', ylabel='y', title='Сінус функція №2')
ax1.grid()

ax2 = fig.add_subplot(2, 2, 3)
ax2.plot(t, s3, c='b',linewidth=2.0)
ax2.set(xlabel='x', ylabel='y', title='Сінус функція №3')
ax2.grid()

ax3 = fig.add_subplot(2, 2, 4)
ax3.plot(t, s4, c='b',linewidth=2.0)
ax3.set(xlabel='x', ylabel='y', title='Сінус функція №4')
ax3.grid()

plt.show()
